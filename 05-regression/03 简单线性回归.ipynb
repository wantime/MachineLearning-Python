# %% [markdown]
# ## 简单线性回归

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1., 2., 3., 4., 5.])
y = np.array([1., 3., 2., 3., 5])

# %%
plt.scatter(x, y)
plt.axis([0, 6, 0, 6])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_mean = np.mean(x)
y_mean = np.mean(y)

# %%
num = 0.0
d = 0.0
for x_i, y_i in zip(x, y):
    num += (x_i - x_mean) * (y_i - y_mean)
    d += (x_i - x_mean) ** 2
print(num)
print(d)
# Out:
# 8.0
# 10.0

# %%
a = num/d
b = y_mean - a * x_mean

# %%
y_hat = a * x + b

# %%
plt.scatter(x, y)
plt.plot(x, y_hat, color='r')
plt.axis([0, 6, 0, 6])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_predict = 6
y_predict = a * x_predict + b
y_predict
# Out:
# 5.2

# %% [markdown]
# ## 封装simple linear regression
#
# [code](ML/SimpleLinearRegression.py)

# %%
from ML.SimpleLinearRegression import SimpleLinearRegression1

# %%
reg1 = SimpleLinearRegression1()
reg1.fit(x, y)
reg1.predict(np.array([x_predict]))
# Out:
# array([5.2])

# %%
reg1.a_
# Out:
# 0.8

# %%
reg1.b_
# Out:
# 0.39999999999999947

# %%
y_hat1 = reg1.predict(x)

# %%
plt.scatter(x, y)
plt.plot(x, y_hat1, color='r')
plt.axis([0, 6, 0, 6])
plt.show()

# %% [markdown]
# ## 向量化
# [code](ML/SimpleLinearRegression.py)

# %%
from ML.SimpleLinearRegression import SimpleLinearRegression2

reg2 = SimpleLinearRegression2()
reg2.fit(x, y)
reg2.predict(np.array([x_predict]))
# Out:
# array([5.2])

# %%
print(reg2.a_)
print(reg2.b_)
# Out:
# 0.8
# 0.39999999999999947
