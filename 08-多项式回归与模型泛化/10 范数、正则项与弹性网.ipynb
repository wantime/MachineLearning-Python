# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Lp范数

# %% [markdown]
# ## L2正则项

# %% [markdown]
# ## L1正则项

# %% [markdown]
# ## L0正则项

# %% [markdown]
# ## 弹性网 Elastic Net
# ![image.png](attachment:image.png)
