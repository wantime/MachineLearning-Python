# %% [markdown]
# ## Pricinpal Component Analysis:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 将每个向量投影到目标向量上，dot product

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 向量化

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
