# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 最值归一化 Normalization
# (x-xmin)/(xmax-xmin)

# %%
x = np.random.randint(0, 100, size=100)

# %%
x
# Out:
# array([66, 36, 21, 70, 29, 58, 17, 72, 17, 11, 77,  4, 96, 30, 99, 25, 51,
#        96, 65,  1, 37,  5, 59, 92, 67, 58, 21, 89, 80, 80, 47, 79, 40, 16,
#        31, 44, 12, 65, 60, 14, 87, 58, 39, 54, 98, 56,  5, 69, 48, 95, 48,
#        12, 44, 61, 91, 30,  5,  8, 17, 20, 39, 55, 65, 19, 43, 18, 62, 29,
#        36, 10, 46, 89, 63, 14, 31, 81, 76, 77, 72, 12, 58, 17, 36, 66, 16,
#        48,  8, 23, 31, 73, 30, 41, 90, 38, 80, 17, 19, 56, 36, 90])

# %%
(x - np.min(x)) / (np.max(x) - np.min(x))
# Out:
# array([0.66326531, 0.35714286, 0.20408163, 0.70408163, 0.28571429,
#        0.58163265, 0.16326531, 0.7244898 , 0.16326531, 0.10204082,
#        0.7755102 , 0.03061224, 0.96938776, 0.29591837, 1.        ,
#        0.24489796, 0.51020408, 0.96938776, 0.65306122, 0.        ,
#        0.36734694, 0.04081633, 0.59183673, 0.92857143, 0.67346939,
#        0.58163265, 0.20408163, 0.89795918, 0.80612245, 0.80612245,
#        0.46938776, 0.79591837, 0.39795918, 0.15306122, 0.30612245,
#        0.43877551, 0.1122449 , 0.65306122, 0.60204082, 0.13265306,
#        0.87755102, 0.58163265, 0.3877551 , 0.54081633, 0.98979592,
#        0.56122449, 0.04081633, 0.69387755, 0.47959184, 0.95918367,
#        0.47959184, 0.1122449 , 0.43877551, 0.6122449 , 0.91836735,
#        0.29591837, 0.04081633, 0.07142857, 0.16326531, 0.19387755,
#        0.3877551 , 0.55102041, 0.65306122, 0.18367347, 0.42857143,
#        0.17346939, 0.62244898, 0.28571429, 0.35714286, 0.09183673,
#        0.45918367, 0.89795918, 0.63265306, 0.13265306, 0.30612245,
#        0.81632653, 0.76530612, 0.7755102 , 0.7244898 , 0.1122449 ,
#        0.58163265, 0.16326531, 0.35714286, 0.66326531, 0.15306122,
#        0.47959184, 0.07142857, 0.2244898 , 0.30612245, 0.73469388,
#        0.29591837, 0.40816327, 0.90816327, 0.37755102, 0.80612245,
#        0.16326531, 0.18367347, 0.56122449, 0.35714286, 0.90816327])

# %%
x = np.random.randint(0 ,100, (50, 2))

# %%
x[:10,:]
# Out:
# array([[49, 46],
#        [79, 91],
#        [11, 71],
#        [95, 34],
#        [42, 14],
#        [19, 13],
#        [ 3, 63],
#        [83, 54],
#        [77, 49],
#        [98, 75]])

# %%
x = np.array(x, dtype=float)
x[:10,:]
# Out:
# array([[49., 46.],
#        [79., 91.],
#        [11., 71.],
#        [95., 34.],
#        [42., 14.],
#        [19., 13.],
#        [ 3., 63.],
#        [83., 54.],
#        [77., 49.],
#        [98., 75.]])

# %%
x[:,0] = (x[:,0] - np.min(x[:,0])) / (np.max(x[:,0]) - np.min(x[:,0]))

# %%
x[:,1] = (x[:,1] - np.min(x[:,1])) / (np.max(x[:,1]) - np.min(x[:,1]))

# %%
plt.scatter(x[:,0],x[:,1])
plt.show()

# %%
np.mean(x[:,0])
# Out:
# 0.5463265306122449

# %%
np.std(x[:,0])
# Out:
# 0.286087292957942

# %%
np.mean(x[:,1])
# Out:
# 0.48329896907216496

# %%
np.std(x[:,1])
# Out:
# 0.30725551540749607

# %% [markdown]
# ## 均值方差归一化 Standardization
# ![image.png](attachment:image.png)

# %%
X2 = np.random.randint(0, 100, (50, 2))

# %%
X2 = np.array(X2, dtype=float)

# %%
X2[:,0] = (X2[:,0] - np.mean(X2[:,0])) / np.std(X2[:,0])

# %%
X2[:,1] = (X2[:,1] - np.mean(X2[:,1])) / np.std(X2[:,1])

# %%
plt.scatter(X2[:,0],X2[:,1])
plt.show()

# %%
np.mean(X2[:,0])
# Out:
# 1.1102230246251565e-16

# %%
np.std(X2[:,0])
# Out:
# 1.0

# %%
np.mean(X2[:,1])
# Out:
# -9.769962616701378e-17

# %%
np.std(X2[:,1])
# Out:
# 1.0
